# %%
import pandas as pd

# %%
df = pd.read_csv('product.csv')

# %%
df
# Out:
#          Date   Product Region  Units Sold  Unit Price  Total Revenue
# 0  2024-01-01  Widget A  North         100        10.0         1000.0
# 1  2024-01-02  Widget B  South         150        12.5         1875.0
# 2  2024-01-03  Widget A   East         200        10.0         2000.0
# 3  2024-01-04  Widget C   West         120        15.0         1800.0
# 4  2024-01-05  Widget B  North          90        12.5         1125.0

# %%
# Calculate the total revenue generated across all sale
total_revenue = df['Total Revenue'].sum()
print(f'total revenue ${total_revenue}')
# Out:
# total revenue $7800.0

# %%
# Group the data by Region and find the total Units Sold for each region.
unit_by_origin = df.groupby('Region')['Units Sold'].sum()
unit_by_origin
# Out:
# Region
# East     200
# North    190
# South    150
# West     120
# Name: Units Sold, dtype: int64

# %%
# Identify the date with the highest Total Revenue.
max_revenue = df.loc[df['Total Revenue'].idxmax(), 'Date']
max_revenue
# Out:
# '2024-01-03'

# %%
# Filter and display all records where the Product is "Widget b"

# %%
# Calculate the average Unit Price for each Product.

# %%
# Add a new column called Revenue per Unit calculated as Total Revenue / Units Sold.# Add the new column

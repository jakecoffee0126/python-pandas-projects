# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns

# %%
plt.style.use('ggplot')

# %%
#extend show 200 columns, otherwise, it will show with ...

pd.set_option('display.max_columns', 200)

# %%
df = pd.read_csv('coaster_db.csv')

# %%
df.shape
# Out:
# (1087, 56)

# %%
df.head(5)
# Out:
#                              coaster_name          Length             Speed  \
# 0                      Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway             NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)             NaN               NaN
# 3            Loop the Loop (Coney Island)             NaN               NaN
# 4            Loop the Loop (Young's Pier)             NaN               NaN
#
#                          Location   Status   Opening date   Type  \
# 0                    Coney Island  Removed  June 16, 1884   Wood
# 1                   Sea Lion Park  Removed           1895   Wood
# 2  Cleveland, Ohio, United States   Closed            NaN  Other
# 3                           Other  Removed           1901  Steel
# 4                           Other  Removed           1901  Steel
#
#              Manufacturer Height restriction        Model        Height  \
# ...

# %%
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
df.dtypes
# Out:
# coaster_name                      object
# Length                            object
# Speed                             object
# Location                          object
# Status                            object
# Opening date                      object
# Type                              object
# Manufacturer                      object
# Height restriction                object
# Model                             object
# Height                            object
# Inversions                       float64
# Lift/launch system                object
# Cost                              object
# Trains                            object
# Park section                      object
# Duration                          object
# Capacity                          object
# G-force                           object
# Designer                          object
# Max vertical angle                object
# Drop                              object
# Soft opening date                 object
# ...

# %%
df.describe()
# Out:
#        Inversions  year_introduced    latitude   longitude  speed1_value  \
# count  932.000000      1087.000000  812.000000  812.000000    937.000000
# mean     1.547210      1994.986201   38.373484  -41.595373     53.850374
# std      2.114073        23.475248   15.516596   72.285227     23.385518
# min      0.000000      1884.000000  -48.261700 -123.035700      5.000000
# 25%      0.000000      1989.000000   35.031050  -84.552200     40.000000
# 50%      0.000000      2000.000000   40.289800  -76.653600     50.000000
# 75%      3.000000      2010.000000   44.799600    2.778100     63.000000
# max     14.000000      2022.000000   63.230900  153.426500    240.000000
#
#         speed_mph  height_value   height_ft  Inversions_clean  Gforce_clean
# count  937.000000    965.000000  171.000000       1087.000000    362.000000
# mean    48.617289     89.575171  101.996491          1.326587      3.824006
# std     16.678031    136.246444   67.329092          2.030854      0.989998
# ...

# %%
df = df[['coaster_name',
         # 'Length', 'Speed',
         'Location', 'Status',
         # 'Opening date',
         #   'Type',
         'Manufacturer',
         #     'Height restriction', 'Model', 'Height',
         #        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
         #        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
         #        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
         #        'Track layout', 'Fastrack available', 'Soft opening date.1',
         #        'Closing date',
         #     'Opened',
         # 'Replaced by', 'Website',
         #        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
         #        'Single rider line available', 'Restraint Style',
         #        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
         'year_introduced',
        'latitude', 'longitude',
         'Type_Main',
         'opening_date_clean',
         # 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
         'speed_mph',
         # 'height_value', 'height_unit',
         'height_ft',
         'Inversions_clean', 'Gforce_clean']]

# %%
df.columns
# Out:
# Index(['coaster_name', 'Location', 'Status', 'Manufacturer', 'year_introduced',
#        'latitude', 'longitude', 'Type_Main', 'opening_date_clean', 'speed_mph',
#        'height_ft', 'Inversions_clean', 'Gforce_clean'],
#       dtype='object')

# %%
# Example of dropping columns
# df.drop(['Opening date'], axis=1) #provide axis, to only drop the column not the row

# %%
df = df[['coaster_name',
         # 'Length', 'Speed',
         'Location', 'Status',
         # 'Opening date',
         #   'Type',
         'Manufacturer',
         #     'Height restriction', 'Model', 'Height',
         #        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
         #        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
         #        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
         #        'Track layout', 'Fastrack available', 'Soft opening date.1',
         #        'Closing date',
         #     'Opened',
         # 'Replaced by', 'Website',
         #        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
         #        'Single rider line available', 'Restraint Style',
         #        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
         'year_introduced',
        'latitude', 'longitude',
         'Type_Main',
         'opening_date_clean',
         # 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
         'speed_mph',
         # 'height_value', 'height_unit',
         'height_ft',
         'Inversions_clean', 'Gforce_clean']].copy()

# %%
df.shape
# Out:
# (1087, 13)

# %%
df.dtypes
# Out:
# coaster_name           object
# Location               object
# Status                 object
# Manufacturer           object
# year_introduced         int64
# latitude              float64
# longitude             float64
# Type_Main              object
# opening_date_clean     object
# speed_mph             float64
# height_ft             float64
# Inversions_clean        int64
# Gforce_clean          float64
# dtype: object

# %%
df['opening_date_clean']=pd.to_datetime(df['opening_date_clean'])
#pd.to_numeric(df['year_introduced'])

# %%
df.dtypes
# Out:
# coaster_name                  object
# Location                      object
# Status                        object
# Manufacturer                  object
# year_introduced                int64
# latitude                     float64
# longitude                    float64
# Type_Main                     object
# opening_date_clean    datetime64[ns]
# speed_mph                    float64
# height_ft                    float64
# Inversions_clean               int64
# Gforce_clean                 float64
# dtype: object

# %%
#Rename our columns
df.columns
# Out:
# Index(['coaster_name', 'Location', 'Status', 'Manufacturer', 'year_introduced',
#        'latitude', 'longitude', 'Type_Main', 'opening_date_clean', 'speed_mph',
#        'height_ft', 'Inversions_clean', 'Gforce_clean'],
#       dtype='object')

# %%
df = df.rename(columns={
    'coaster_name': 'Coaster_Name',
    'year_introduced': 'Year_Introduced',
    'latitude': 'Latitude',
    'longitude': 'Longitude',
    'opening_date_clean': 'Opening_Date_Clean',
    'speed_mph': 'Speed_mpg',
    'height_ft': 'Height_ft'
})

# %%
df.columns
# Out:
# Index(['Coaster_Name', 'Location', 'Status', 'Manufacturer', 'Year_Introduced',
#        'Latitude', 'Longitude', 'Type_Main', 'Opening_Date_Clean', 'Speed_mpg',
#        'Height_ft', 'Inversions_clean', 'Gforce_clean'],
#       dtype='object')

# %%
df.head()
# Out:
#                              Coaster_Name                        Location  \
# 0                      Switchback Railway                    Coney Island
# 1                       Flip Flap Railway                   Sea Lion Park
# 2  Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3            Loop the Loop (Coney Island)                           Other
# 4            Loop the Loop (Young's Pier)                           Other
#
#     Status            Manufacturer  Year_Introduced  Latitude  Longitude  \
# 0  Removed  LaMarcus Adna Thompson             1884   40.5740   -73.9780
# 1  Removed            Lina Beecher             1895   40.5780   -73.9790
# 2   Closed                     NaN             1896   41.5800   -81.5700
# 3  Removed          Edwin Prescott             1901   40.5745   -73.9780
# 4  Removed          Edwin Prescott             1901   39.3538   -74.4342
#
#   Type_Main Opening_Date_Clean  Speed_mpg  Height_ft  Inversions_clean  \
# ...

# %%
df.isna()
# Out:
#       Coaster_Name  Location  Status  Manufacturer  Year_Introduced  Latitude  \
# 0            False     False   False         False            False     False
# 1            False     False   False         False            False     False
# 2            False     False   False          True            False     False
# 3            False     False   False         False            False     False
# 4            False     False   False         False            False     False
# ...            ...       ...     ...           ...              ...       ...
# 1082         False     False    True         False            False      True
# 1083         False     False   False         False            False     False
# 1084         False     False    True         False            False      True
# 1085         False     False   False         False            False      True
# 1086         False     False   False         False            False      True
#
# ...

# %%
df.isna().sum()
# Out:
# Coaster_Name            0
# Location                0
# Status                213
# Manufacturer           59
# Year_Introduced         0
# Latitude              275
# Longitude             275
# Type_Main               0
# Opening_Date_Clean    250
# Speed_mpg             150
# Height_ft             916
# Inversions_clean        0
# Gforce_clean          725
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1082    False
# 1083    False
# 1084    False
# 1085    False
# 1086    False
# Length: 1087, dtype: bool

# %%
df.duplicated(subset=['Coaster_Name'])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1082     True
# 1083    False
# 1084     True
# 1085    False
# 1086    False
# Length: 1087, dtype: bool

# %%
# Check for duplicate coaster name
df.loc[df.duplicated(subset=['Coaster_Name'])]  # 97 rows × 13 columns, there are 97 rows duplicated
# Out:
#                             Coaster_Name                   Location  \
# 43                 Crystal Beach Cyclone         Crystal Beach Park
# 60                           Derby Racer               Revere Beach
# 61           Blue Streak (Conneaut Lake)         Conneaut Lake Park
# 167        Big Thunder Mountain Railroad                      Other
# 237    Thunder Run (Canada's Wonderland)        Canada's Wonderland
# ...                                  ...                        ...
# 1063                  Lil' Devil Coaster  Six Flags Great Adventure
# 1064  Little Dipper (Conneaut Lake Park)         Conneaut Lake Park
# 1080                          Iron Gwazi    Busch Gardens Tampa Bay
# 1082             American Dreier Looping                      Other
# 1084           Tron Lightcycle Power Run                      Other
#
#                   Status                                       Manufacturer  \
# ...

# %%
# Checking an example duplicate
df.query('Coaster_Name == "Crystal Beach Cyclone"')
# Out:
#              Coaster_Name            Location   Status        Manufacturer  \
# 39  Crystal Beach Cyclone  Crystal Beach Park  Removed  Traver Engineering
# 43  Crystal Beach Cyclone  Crystal Beach Park  Removed  Traver Engineering
#
#     Year_Introduced  Latitude  Longitude Type_Main Opening_Date_Clean  \
# 39             1926   42.8617   -79.0598      Wood         1926-01-01
# 43             1927   42.8617   -79.0598      Wood         1926-01-01
#
#     Speed_mpg  Height_ft  Inversions_clean  Gforce_clean
# 39       60.0        NaN                 0           4.0
# 43       60.0        NaN                 0           4.0

# %%
df.columns
# Out:
# Index(['Coaster_Name', 'Location', 'Status', 'Manufacturer', 'Year_Introduced',
#        'Latitude', 'Longitude', 'Type_Main', 'Opening_Date_Clean', 'Speed_mpg',
#        'Height_ft', 'Inversions_clean', 'Gforce_clean'],
#       dtype='object')

# %%
df.duplicated(subset=['Coaster_Name','Location','Opening_Date_Clean']) #.sum()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1082     True
# 1083    False
# 1084     True
# 1085    False
# 1086    False
# Length: 1087, dtype: bool

# %%
# list all the duplicated dataset
df.loc[df.duplicated(
    subset=['Coaster_Name', 'Location', 'Opening_Date_Clean'])]
# Out:
#                             Coaster_Name                   Location  \
# 43                 Crystal Beach Cyclone         Crystal Beach Park
# 60                           Derby Racer               Revere Beach
# 61           Blue Streak (Conneaut Lake)         Conneaut Lake Park
# 167        Big Thunder Mountain Railroad                      Other
# 237    Thunder Run (Canada's Wonderland)        Canada's Wonderland
# ...                                  ...                        ...
# 1063                  Lil' Devil Coaster  Six Flags Great Adventure
# 1064  Little Dipper (Conneaut Lake Park)         Conneaut Lake Park
# 1080                          Iron Gwazi    Busch Gardens Tampa Bay
# 1082             American Dreier Looping                      Other
# 1084           Tron Lightcycle Power Run                      Other
#
#                   Status                                       Manufacturer  \
# ...

# %%
~df.duplicated(subset=['Coaster_Name', 'Location','Opening_Date_Clean']) #inverse the dataset
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1082    False
# 1083     True
# 1084    False
# 1085     True
# 1086     True
# Length: 1087, dtype: bool

# %%
#list all the NON duplicated dataset
df.loc[~df.duplicated(
    subset=['Coaster_Name', 'Location', 'Opening_Date_Clean'])]
# Out:
#                                 Coaster_Name                        Location  \
# 0                         Switchback Railway                    Coney Island
# 1                          Flip Flap Railway                   Sea Lion Park
# 2     Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3               Loop the Loop (Coney Island)                           Other
# 4               Loop the Loop (Young's Pier)                           Other
# ...                                      ...                             ...
# 1079            Ice Breaker (roller coaster)                SeaWorld Orlando
# 1081                   Leviathan (Sea World)                       Sea World
# 1083               Pantheon (roller coaster)      Busch Gardens Williamsburg
# 1085                                 Tumbili                  Kings Dominion
# 1086          Wonder Woman Flight of Courage        Six Flags Magic Mountain
#
# ...

# %%
#reset the index, so the first column number won't jump, like 1079 next is 1081, we want next to be 1080

df.loc[~df.duplicated(
    subset=['Coaster_Name', 'Location', 'Opening_Date_Clean'])].reset_index()
# Out:
#      index                            Coaster_Name  \
# 0        0                      Switchback Railway
# 1        1                       Flip Flap Railway
# 2        2  Switchback Railway (Euclid Beach Park)
# 3        3            Loop the Loop (Coney Island)
# 4        4            Loop the Loop (Young's Pier)
# ..     ...                                     ...
# 985   1079            Ice Breaker (roller coaster)
# 986   1081                   Leviathan (Sea World)
# 987   1083               Pantheon (roller coaster)
# 988   1085                                 Tumbili
# 989   1086          Wonder Woman Flight of Courage
#
#                            Location              Status  \
# 0                      Coney Island             Removed
# 1                     Sea Lion Park             Removed
# 2    Cleveland, Ohio, United States              Closed
# 3                             Other             Removed
# 4                             Other             Removed
# ...

# %%
# it created a new index column, which is the old index, so to drop that old index column,
# we put 'drop=True'
df.loc[~df.duplicated(
    subset=['Coaster_Name', 'Location', 'Opening_Date_Clean'])].reset_index(drop=True)
# Out:
#                                Coaster_Name                        Location  \
# 0                        Switchback Railway                    Coney Island
# 1                         Flip Flap Railway                   Sea Lion Park
# 2    Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3              Loop the Loop (Coney Island)                           Other
# 4              Loop the Loop (Young's Pier)                           Other
# ..                                      ...                             ...
# 985            Ice Breaker (roller coaster)                SeaWorld Orlando
# 986                   Leviathan (Sea World)                       Sea World
# 987               Pantheon (roller coaster)      Busch Gardens Williamsburg
# 988                                 Tumbili                  Kings Dominion
# 989          Wonder Woman Flight of Courage        Six Flags Magic Mountain
#
# ...

# %%
# In Pandas, the .copy() method is used to create a duplicate of a DataFrame or Series. 
# This method is crucial for ensuring data integrity and avoiding unintended modifications 
# when performing operations.
df=df.loc[~df.duplicated(
    subset=['Coaster_Name', 'Location', 'Opening_Date_Clean'])].reset_index(drop=True).copy()

# %%
df.shape
# Out:
# (990, 13)

# %%
df.columns
# Out:
# Index(['Coaster_Name', 'Location', 'Status', 'Manufacturer', 'Year_Introduced',
#        'Latitude', 'Longitude', 'Type_Main', 'Opening_Date_Clean', 'Speed_mpg',
#        'Height_ft', 'Inversions_clean', 'Gforce_clean'],
#       dtype='object')

# %%
df['Year_Introduced'].value_counts()
# Out:
# Year_Introduced
# 1999    46
# 2000    45
# 1998    30
# 2001    29
# 2002    28
#         ..
# 1952     1
# 1956     1
# 1961     1
# 1955     1
# 1959     1
# Name: count, Length: 101, dtype: int64

# %%
df['Year_Introduced'].value_counts().head(10).plot(kind='bar', title="Top Years Coasters Intruduced")
# Out:
# <Axes: xlabel='Year_Introduced'>

# %%
ax = df['Year_Introduced'].value_counts().head(10).plot(
    kind='bar', title="Top 10 Years Coasters Intruduced")
ax.set_xlabel('Year Introduced')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
ax = df['Speed_mpg'].plot(kind='hist', bins=20, title='Coaster Sppend (mph)')
ax.set_xlabel('Speed(mph)')
# Out:
# Text(0.5, 0, 'Speed(mph)')

# %%
ax = df['Speed_mpg'].plot(kind='kde',title='Coaster Sppend (mph)')
ax.set_xlabel('Speed(mph)')
# Out:
# Text(0.5, 0, 'Speed(mph)')

# %%
df.columns
# Out:
# Index(['Coaster_Name', 'Location', 'Status', 'Manufacturer', 'Year_Introduced',
#        'Latitude', 'Longitude', 'Type_Main', 'Opening_Date_Clean', 'Speed_mpg',
#        'Height_ft', 'Inversions_clean', 'Gforce_clean'],
#       dtype='object')

# %%
df = df.rename(columns={'Speed_mpg': 'Speed_mph'})

# %%
df.columns
# Out:
# Index(['Coaster_Name', 'Location', 'Status', 'Manufacturer', 'Year_Introduced',
#        'Latitude', 'Longitude', 'Type_Main', 'Opening_Date_Clean', 'Speed_mph',
#        'Height_ft', 'Inversions_clean', 'Gforce_clean'],
#       dtype='object')

# %%
df.plot(kind='scatter',
        x='Speed_mph',
        y='Height_ft',
        title='Coaster Speed vs. Height')
# Out:
# <Axes: title={'center': 'Coaster Speed vs. Height'}, xlabel='Speed_mph', ylabel='Height_ft'>

# %%
plt.show()
# it above print out <Axes: title={'center': 'Coaster Speed vs. Height'}, xlabel='Speed_mph', ylabel='Height_ft'>

# %%
sns.scatterplot(x='Speed_mph',
                y='Height_ft',
                hue='Year_Introduced',
                data=df)
# Out:
# <Axes: xlabel='Speed_mph', ylabel='Height_ft'>

# %%
ax = sns.scatterplot(x='Speed_mph',
                     y='Height_ft',
                     hue='Year_Introduced',
                     data=df)
ax.set_title('Coaster Speed vs. Height')
plt.show()

# %%
df.columns
# Out:
# Index(['Coaster_Name', 'Location', 'Status', 'Manufacturer', 'Year_Introduced',
#        'Latitude', 'Longitude', 'Type_Main', 'Opening_Date_Clean', 'Speed_mph',
#        'Height_ft', 'Inversions_clean', 'Gforce_clean'],
#       dtype='object')

# %%
df=df.rename(columns={
    'Inversions_clean': 'Inversions',
    'Gforce_clean':'Gforce'})

# %%
sns.pairplot(df, vars=['Year_Introduced',
                       'Speed_mph',
                       'Height_ft',
                       'Inversions',
                       'Gforce'],
                       hue='Type_Main')
#plt.show()
plt.savefig('pairplot.png') #save as an image instead of plt.show()

# %%
df.columns
# Out:
# Index(['Coaster_Name', 'Location', 'Status', 'Manufacturer', 'Year_Introduced',
#        'Latitude', 'Longitude', 'Type_Main', 'Opening_Date_Clean', 'Speed_mph',
#        'Height_ft', 'Inversions', 'Gforce'],
#       dtype='object')

# %%
df[['Year_Introduced','Speed_mph','Height_ft','Gforce']]
# Out:
#      Year_Introduced  Speed_mph  Height_ft  Gforce
# 0               1884        6.0        NaN     2.9
# 1               1895        NaN        NaN    12.0
# 2               1896        NaN        NaN     NaN
# 3               1901        NaN        NaN     NaN
# 4               1901        NaN        NaN     NaN
# ..               ...        ...        ...     ...
# 985             2022       52.0        NaN     NaN
# 986             2022       49.7      105.0     NaN
# 987             2022       73.0        NaN     NaN
# 988             2022       34.0        NaN     NaN
# 989             2022       58.0        NaN     NaN
#
# [990 rows x 4 columns]

# %%
df[['Year_Introduced', 'Speed_mph','Height_ft','Gforce']].dropna()
# Out:
#      Year_Introduced  Speed_mph  Height_ft  Gforce
# 179             1981       46.6       95.1     3.5
# 221             1985       60.0      145.0     5.2
# 240             1987       49.7      147.6     3.0
# 262             1989       37.3       83.7     4.0
# 265             1989       55.9      118.1     3.9
# ..               ...        ...        ...     ...
# 901             2016       71.5      183.7     4.0
# 903             2017       71.5      202.1     4.3
# 923             2018       88.2      252.6     4.8
# 955             2019       75.2      206.0     4.0
# 961             2020       62.1      142.7     4.5
#
# [67 rows x 4 columns]

# %%
df[['Year_Introduced', 'Speed_mph', 'Height_ft','Gforce']].dropna().corr()
# Out:
#                  Year_Introduced  Speed_mph  Height_ft    Gforce
# Year_Introduced         1.000000   0.171978   0.135413  0.160247
# Speed_mph               0.171978   1.000000   0.733999  0.607383
# Height_ft               0.135413   0.733999   1.000000  0.466482
# Gforce                  0.160247   0.607383   0.466482  1.000000

# %%
df_corr = df[['Year_Introduced', 'Speed_mph', 'Height_ft', 'Gforce']].dropna().corr()

# %%
sns.heatmap(df_corr, annot=True) #annot, to add correlation number
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Coaster_Name', 'Location', 'Status', 'Manufacturer', 'Year_Introduced',
#        'Latitude', 'Longitude', 'Type_Main', 'Opening_Date_Clean', 'Speed_mph',
#        'Height_ft', 'Inversions', 'Gforce'],
#       dtype='object')

# %%
# What are the locations with the fastest roller coasters (minimum of 10)?

# %%
df['Location'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0                        Coney Island
# 1                       Sea Lion Park
# 2      Cleveland, Ohio, United States
# 3                               Other
# 4                               Other
#                     ...
# 985                  SeaWorld Orlando
# 986                         Sea World
# 987        Busch Gardens Williamsburg
# 988                    Kings Dominion
# 989          Six Flags Magic Mountain
# Name: Location, Length: 990, dtype: object>

# %%
df.query('Location != "Other"')\
    .groupby('Location')['Speed_mph']\
    .agg(['mean', 'count'])
# Out:
#                                                      mean  count
# Location
# 2904 Fantasy Way Myrtle Beach, South Carolina, ...    NaN      0
# 63rd and N.W. Expressway, Oklahoma City, Oklaho...    NaN      0
# 8039 Beach BoulevardBuena Park, California 9062...    NaN      0
# Adlabs Imagica                                      42.50      1
# Adventure City                                      31.10      1
# ...                                                   ...    ...
# Xishuangbanna Theme Park                            52.80      1
# Yomiuriland                                         51.45      4
# ZDT's Amusement Park                                40.40      1
# Zoosafari Fasanolandia                              43.50      1
# Đại Nam Văn Hiến                                    46.60      1
#
# [279 rows x 2 columns]

# %%
df.query('Location != "Other"')\
    .groupby('Location')['Speed_mph']\
    .agg(['mean', 'count'])\
    .query('count > = 10')\
    .sort_values('mean')
# Out:
#                                  mean  count
# Location
# Alton Towers                42.791667     12
# Carowinds                   43.571429     14
# Kings Island                49.273684     19
# Hersheypark                 50.576923     13
# Kings Dominion              52.083333     12
# Six Flags Great Adventure   53.036364     11
# Canada's Wonderland         53.533333     12
# Six Flags Magic Mountain    57.241176     17
# Cedar Point                 57.833333     18
# Busch Gardens Williamsburg  58.318182     11

# %%
df.query('Location != "Other"')\
    .groupby('Location')['Speed_mph']\
    .agg(['mean', 'count'])\
    .query('count > = 10')\
    .sort_values('mean')['mean']\
    .plot(kind='barh', figsize=(10, 5), title='Average Coast Speed by Location')
# Out:
# <Axes: title={'center': 'Average Coast Speed by Location'}, ylabel='Location'>
